# %% [markdown]
# # HPO ID Mapping

# %%
import requests
import pandas as pd
import json
from pprint import pprint

# %%
# import the list of HPO DOIs
queryIds = pd.read_csv('missing_dois_for_lookup.csv')

# %%
queryIds.head()
# Out:
#                                doi
# 0     10.1080/15374416.2014.945214
# 1        10.1016/j.jbi.2015.06.026
# 2        10.1007/s10803-017-3030-7
# 3   10.1016/j.psychres.2015.11.012
# 4  10.4018/978-1-5225-2492-2.ch006

# %% [markdown]
# ## Method definitions

# %%
import xml.etree.ElementTree as ET

problemUrls = list()

def printProbUrls():
    pprint(problemUrls)

# check to see if object exists before returning it
def key_check(key, obj):
    if key in obj.keys():
        return str(obj[key])
    else:
        return None
    
def eutils_pmc_search(phrase):
    print(phrase)
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?"
    params = {
        'retmode':'json',
        'db':'pmc',
        'term':phrase,
        'retmax':1000
    }
    composedUrl = None

    try:
        results = requests.get(url=base_url, params=params)
        composedUrl = results.url
        resultsjson = results.json()
        allresults = resultsjson['esearchresult']['idlist']
        pprint(allresults)
        return allresults
    except Exception as e:
        print(e)
        print(composedUrl)
        problemUrls.append(composedUrl)
        return None

def epmc_id_lookup(pubid):
    """
    make a request to europmc api for publication data based on identifer
    arg: ext_id = pmid, pmcid, doi
    """
    base_url = 'http://www.ebi.ac.uk/europepmc/webservices/rest/search'
    params = {
        'query':pubid,
        'resulttype':'core',
        'format': 'json'
    }
    
    try:
        results = requests.get(url=base_url, params=params)
#         print (results.url)
        resultsjson = results.json()
        allresults = resultsjson['resultList']['result']
        
        # if they don't have this ID (if this happens it is usually because of a DOI)
        if(len(allresults)==0):
            return None
        
        # else test if this is a DOI
        else:
            if("10." in pubid):
                """
                searching for PMIDs and PMCIDs gets you a single definitive result; for some reason
                ...searching by DOI gets several results, so iterate and find the one that matches the input ID  
                """
                found = False

                for aresult in allresults:
                    if "doi" in aresult.keys():
                        if (aresult['doi']) == pubid:
                            found = True
                            return aresult
                        # else queried ID is not a DOI but a PMCID or PMID,
                        # ergo the stanza we want is just at index 0
                # if we've iterated through all responses and haven't found a match
                if found==False:
                    print("Exact match not found "+results.url)
                #    pprint(allresults)
            else:
                print ("Warning, searched for "+pubid+ ", not a DOI")
                return allresults[0]

    except Exception as e:
        print("ERROR PARSING: "+ url + " at ")
        print(e)
        return None

def get_pub_yr_crossref(doi):
    """
    when the DOI has no corresponding pmid or pmcid, make a request to crossref api for pubyear
    """
    base_url = 'https://api.crossref.org/works/'
    url = base_url+doi

    try:
        results = requests.get(url).json()
#         pprint(results['message']["created"]["date-parts"][0][0])
 
        if (str(results)=="<Response [404]>"):
            print("NO RESULT: "+url)
            return None
        
        pubyr = None
#         if(results == "Resource not found.") return pubyr
    
        if "published-online" in results['message'].keys():
            pubyr = results['message']["published-online"]["date-parts"][0][0]
#             print("online pubyr: "+str(pubyr))
        else: 
            if "published-print" in results['message'].keys():
                pubyr = results['message']["published-print"]["date-parts"][0][0]  
            else: 
                if "created" in results['message'].keys():
                    pubyr = results['message']["created"]["date-parts"][0][0]   
        print(pubyr)
        return pubyr
    
    except Exception as f:
        print("ERROR PARSING: "+ url)
#         pprint(results)
        print(f)
        return None

# %% [markdown]
# ## Main

# %%
print("Started ...")
problemUrls = list()
results = list()
for index, row in queryIds.iterrows():
    row_dict = {
        'pmcid': None,
        'doi': pubid,
        'pmid': None,
        'pubyear': None,
    }
    if index < 5000:
        if index%5==0:
            print(index)
        # to search by other id use row_dict['pmid]
        pubid = row[0]
        response = epmc_id_lookup(pubid)
        
        if response!=None:
            row_dict['doi'] = pubid #todo fix
            row_dict['pmcid'] = key_check('pmcid',response)
            row_dict['pmid'] = key_check('id',response)
            row_dict['pubyear'] = key_check('pubYear',response)
        else:
#           check to see if it is a DOI
            if ("10." in pubid):
                try: 
                    row_dict['pubyear'] = get_pub_yr_crossref(pubid)
                except Exception as f:
                    print("Failed at crossref: ")
                    print(f)
            else:
                print("Requested "+ pubid + " but this call can only be used with a DOI")
#       append the results, whether from epmc or crossref  
#         pprint(row_dict)   
        results.append(row_dict)
    
printProbUrls()
# Out:
# Started ...
# 0
# 5
# 10
# 15
# 20
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F2041-1480-4-42&resulttype=core&format=json
# 25
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F1752-0509-8-68&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F2041-1480-5-23&resulttype=core&format=json
# 30
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F2041-1480-5-S1-S3&resulttype=core&format=json
# 35
# 40
# 45
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F1755-8794-8-S2-S9&resulttype=core&format=json
# 50
# 55
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1128%2FmBio.01263-15&resulttype=core&format=json
# 60
# 65
# 70
# 75
# 80
# 85
# 90
# 95
# 100
# 105
# 110
# 115
# 120
# 125
# 130
# ERROR PARSING: https://api.crossref.org/works/10.3233/978-1-61499-753-5-131
# Expecting value: line 1 column 1 (char 0)
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.4158%2FEP161688.PS&resulttype=core&format=json
# 135
# 140
# 145
# 150
# 155
# 160
# 165
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1109%2FJBHI.2015.2496424&resulttype=core&format=json
# 170
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1109%2FTCBB.2016.2550443&resulttype=core&format=json
# 175
# 180
# 185
# 190
# ERROR PARSING: https://api.crossref.org/works/10.3233/978-1-61499-432-9-1125
# Expecting value: line 1 column 1 (char 0)
# ERROR PARSING: https://api.crossref.org/works/10.3233/978-1-61499-438-1-409
# Expecting value: line 1 column 1 (char 0)
# 195
# 200
# 205
# 210
# 215
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1109%2FTCBB.2015.2430289&resulttype=core&format=json
# 220
# 225
# 230
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.2147%2FIJN.S24582&resulttype=core&format=json
# 235
# 240
# ERROR PARSING: https://api.crossref.org/works/10.16476/j.pibb.2014.0140
# Expecting value: line 1 column 1 (char 0)
# 245
# 250
# 255
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F1471-2105-12-218&resulttype=core&format=json
# 260
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F2041-1480-2-S2-S5&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F2041-1480-2-S2-S7&resulttype=core&format=json
# 265
# 270
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F1752-0509-6-S3-S20&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F1471-2105-14-103&resulttype=core&format=json
# 275
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F1471-2105-14-263&resulttype=core&format=json
# 280
# 285
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F2041-1480-5-21&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F2041-1480-5-25&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F2041-1480-5-S1-S3&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.7554%2FeLife.02626&resulttype=core&format=json
# 290
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F2041-1480-5-37&resulttype=core&format=json
# 295
# 300
# 305
# 310
# 315
# 320
# 325
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.7554%2FeLife.25835&resulttype=core&format=json
# 330
# ERROR PARSING: https://api.crossref.org/works/10.3233/SW-130112
# Expecting value: line 1 column 1 (char 0)
# 335
# 340
# ERROR PARSING: https://api.crossref.org/works/10.1016/B978-1-907568-97-8.50009-6
# Expecting value: line 1 column 1 (char 0)
# ERROR PARSING: https://api.crossref.org/works/10.3233/978-1-61499-101-4-569
# Expecting value: line 1 column 1 (char 0)
# 345
# ERROR PARSING: https://api.crossref.org/works/10.3233/978-1-61499-289-9-938
# Expecting value: line 1 column 1 (char 0)
# ERROR PARSING: https://api.crossref.org/works/10.1007/978-3-642-35176-1-7
# Expecting value: line 1 column 1 (char 0)
# 350
# 355
# 360
# 365
# 370
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1016%2FB978-0-12-388408-4.00001-0&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1016%2FB978-0-12-398323-7.00001-X&resulttype=core&format=json
# 375
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1016%2FB978-0-12-398323-7.00003-3&resulttype=core&format=json
# 380
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1016%2FS0034-7450%2813%2970023-4&resulttype=core&format=json
# 385
# 390
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1097%2FMCA.0000000000000357&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1109%2FTVCG.2015.2467733&resulttype=core&format=json
# 395
# ERROR PARSING: https://api.crossref.org/works/10.3233/978-1-61499-101-4-88
# Expecting value: line 1 column 1 (char 0)
# ERROR PARSING: https://api.crossref.org/works/10.3233/978-1-61499-101-4-949
# Expecting value: line 1 column 1 (char 0)
# ERROR PARSING: https://api.crossref.org/works/10.3233/978-1-61499-289-9-961
# Expecting value: line 1 column 1 (char 0)
# 400
# ERROR PARSING: https://api.crossref.org/works/10.1007/978-3-642-21043-3-30
# Expecting value: line 1 column 1 (char 0)
# 405
# 410
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1109%2FEMBC.2013.6610290&resulttype=core&format=json
# 415
# 420
# 425
# 430
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1017%2FS0266462300000799&resulttype=core&format=json
# 435
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1161%2FCIRCGENETICS.116.001482&resulttype=core&format=json
# 440
# 445
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F2041-1480-2-9&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F2041-1480-3-5&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F2041-1480-3-17&resulttype=core&format=json
# 450
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1128%2FAAC.00419-13&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F2041-1480-4-16&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F2041-1480-4-42&resulttype=core&format=json
# 455
# 460
# 465
# 470
# 475
# 480
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1603%2FME12169&resulttype=core&format=json
# 485
# 490
# 495
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.3233%2FJAD-161148&resulttype=core&format=json
# 500
# 505
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1197%2Fjamia.M1605&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1197%2Fjamia.M1957&resulttype=core&format=json
# 510
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F1471-2105-12-S8-S2&resulttype=core&format=json
# 515
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F1758-2946-4-9&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F2041-1480-3-S3-S5&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F1479-5876-12-S2-S6&resulttype=core&format=json
# 520
# 525
# ERROR PARSING: https://api.crossref.org/works/10.3233/978-1-60750-949-3-1033
# Expecting value: line 1 column 1 (char 0)
# ERROR PARSING: https://api.crossref.org/works/10.3233/978-1-60750-949-3-449
# Expecting value: line 1 column 1 (char 0)
# ERROR PARSING: https://api.crossref.org/works/10.3233/978-1-60750-949-3-74
# Expecting value: line 1 column 1 (char 0)
# 530
# ERROR PARSING: https://api.crossref.org/works/10.3233/978-1-60750-949-3-763
# Expecting value: line 1 column 1 (char 0)
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1001%2Fjama.271.14.1103&resulttype=core&format=json
# ERROR PARSING: https://api.crossref.org/works/10.1002/(SICI)1097-4571(199105)42:4&lt;297::AID-ASI6&gt;3.0.CO;2-M
# Expecting value: line 1 column 1 (char 0)
# 535
# ERROR PARSING: https://api.crossref.org/works/10.1002/(SICI)1097-4571(199506)46:5&lt;348::AID-ASI6&gt;3.0.CO;2-1
# Expecting value: line 1 column 1 (char 0)
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1007%2FBF00992706&resulttype=core&format=json
# 540
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1016%2F0010-4809%2891%2990035-U&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1016%2F0010-4809%2892%2990003-S&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1016%2F0020-7101%2891%2990036-E&resulttype=core&format=json
# 545
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1016%2F0020-7101%2892%2990032-N&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1016%2F0020-7101%2894%2990023-X&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1016%2F0140-6736%2891%2992731-G&resulttype=core&format=json
# 550
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1016%2F0169-2607%2891%2990007-G&resulttype=core&format=json
# 555
# 560
# 565
# 570
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1016%2FS1532-0464%2802%2900528-2&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1017%2FS0266462300004591&resulttype=core&format=json
# 575
# 580
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1109%2FTITB.2002.1006296&resulttype=core&format=json
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1109%2FTITB.2006.884367&resulttype=core&format=json
# 585
# 590
# 595
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2F1471-2105-9-S3-S2&resulttype=core&format=json
# ERROR PARSING: https://api.crossref.org/works/10.3233/978-1-58603-873-1-22
# Expecting value: line 1 column 1 (char 0)
# ERROR PARSING: https://api.crossref.org/works/10.3233/978-1-60750-044-5-233
# Expecting value: line 1 column 1 (char 0)
# ERROR PARSING: https://api.crossref.org/works/10.3233/978-1-60750-890-8-15
# Expecting value: line 1 column 1 (char 0)
# ERROR PARSING: https://api.crossref.org/works/10.3233/978-1-60750-890-8-257
# Expecting value: line 1 column 1 (char 0)
# 600
# ERROR PARSING: https://api.crossref.org/works/10.3233/978-1-60750-928-8-201
# Expecting value: line 1 column 1 (char 0)
# ERROR PARSING: https://api.crossref.org/works/10.3233/978-1-60750-939-4-475
# Expecting value: line 1 column 1 (char 0)
# ERROR PARSING: https://api.crossref.org/works/10.3233/978-1-61499-538-8-179
# Expecting value: line 1 column 1 (char 0)
# 605
# ERROR PARSING: https://api.crossref.org/works/10.1007/978-3-642-35173-0-12
# Expecting value: line 1 column 1 (char 0)
# 610
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1197%2Fjamia.M1305&resulttype=core&format=json
# 615
# Exact match not found http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1016%2FS1359-6446%2805%2903376-3&resulttype=core&format=json
# []

# %%
newFrame = pd.DataFrame(data=results)
newFrame.to_csv('mapped_ids.csv')

# %%
newFrame
