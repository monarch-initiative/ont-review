# %% [markdown]
# # HPO ID Mapping

# %%
import requests
import pandas as pd
import json
from pprint import pprint

# %%
# import the list of HPO DOIs
hpo = pd.read_csv('HPO_DOI_citations.csv')

# %%
hpo.head()
# Out:
#        10.1186/s13326-017-0144-y
# 0  10.1080/03610926.2016.1197254
# 1      10.1016/j.jbi.2017.07.012
# 2      10.1007/s11427-017-9099-3
# 3      10.1007/s00103-017-2538-5
# 4       10.3389/FPUBH.2017.00066

# %% [markdown]
# ## Method definitions

# %%
import xml.etree.ElementTree as ET

# check to see if object exists before returning it
def key_check(key, obj):
    if key in obj.keys():
        return obj[key]
    else:
        return None

def epmc_id_lookup(pubid):
    """
    make a request to europmc api for publication data based on identifer
    arg: ext_id = pmid, pmcid, doi
    """
    base_url = 'http://www.ebi.ac.uk/europepmc/webservices/rest/search'
    params = {
        'query': pubid,
        'resulttype': 'core',
        'format': 'json'
    }
    
    try:
        results = requests.get(url=base_url, params=params)
        print (results.url)
        resultsjson = results.json()
        allresults = resultsjson['resultList']['result']
        #       test if this is a DOI
        if("10." in pubid):
            """
            searching for PMIDs and PMCIDs gets you a single definitive result; for some reason
            ...searching by DOI gets several results, so iterate and find the one that matches the input ID  
            """
            for aresult in allresults:
                if (aresult['doi']) == pubid:
                    return aresult
                # else queried ID is not a DOI but a PMCID or PMID,
                # ergo the stanza we want is just at index 0
                else:
                    print ()
                    return allresults[0]
    except Exception as e:
        print(e)
        return None

def get_pub_yr_crossref(doi):
    """
    when the DOI has no corresponding pmid or pmcid, make a request to crossref api for pubyear
    """
    base_url = 'https://api.crossref.org/works/'
    url = base_url+doi
    print(url)
    try:
        results = requests.get(url).json()
        pubyr = None

        if "published-online" in results['message'].keys():
            pubyr = results['message']["published-online"]["date-parts"][0][0]
#             print("online pubyr: "+str(pubyr))
        else: 
            pubyr = results['message']["published-print"]["date-parts"][0][0]    
#             print("print pubyr: "+str(pubyr))
        return pubyr
    
    except Exception as e:
        print(e)
        return None

# %% [markdown]
# ## Main

# %%
results = list()
for index, row in hpo.iterrows():
    row_dict = {
        'pmcid': None,
        'doi': row[0],
        'pmid': None,
        'pubyear': None,
    }
    if index < 500:
        # to search by other id use row_dict['pmid]
        pubid = row_dict['doi']
        response = epmc_id_lookup(pubid)
        
        if response!=None:
            row_dict['pmcid'] = key_check('pmcid',response)
            row_dict['pmid'] = key_check('id',response)
            row_dict['pubyear'] = key_check('pubYear',response)
        else:
#           check to see if it is a DOI
            if ("10." in pubid):
                try: 
                    row_dict['pubyear'] = get_pub_yr_crossref(pubid)
                except Exception as f:
                    print ("Failed at crossref: "+ f)
            else:
                print("Requested "+ pubid + " but this call can only be used with a DOI")
#       append the results, whether from epmc or crossref  
        pprint(row_dict)   
        results.append(row_dict)
# Out:
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1080%2F03610926.2016.1197254&resulttype=core&format=json
# https://api.crossref.org/works/10.1080/03610926.2016.1197254
# {'doi': '10.1080/03610926.2016.1197254',
#  'pmcid': None,
#  'pmid': None,
#  'pubyear': 2016}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1016%2Fj.jbi.2017.07.012&resulttype=core&format=json
# {'doi': '10.1016/j.jbi.2017.07.012',
#  'pmcid': None,
#  'pmid': '28729030',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1007%2Fs11427-017-9099-3&resulttype=core&format=json
# {'doi': '10.1007/s11427-017-9099-3',
#  'pmcid': None,
#  'pmid': '28639105',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1007%2Fs00103-017-2538-5&resulttype=core&format=json
# {'doi': '10.1007/s00103-017-2538-5',
#  'pmcid': None,
#  'pmid': '28293716',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.3389%2FFPUBH.2017.00066&resulttype=core&format=json
#
# {'doi': '10.3389/FPUBH.2017.00066',
#  'pmcid': 'PMC5379772',
#  'pmid': '28421178',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2Fs12864-016-3263-4&resulttype=core&format=json
# {'doi': '10.1186/s12864-016-3263-4',
#  'pmcid': 'PMC5310285',
#  'pmid': '28198675',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.2144%2F000114492&resulttype=core&format=json
# {'doi': '10.2144/000114492',
#  'pmcid': None,
#  'pmid': '28118812',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1093%2Fnar%2Fgkw1039&resulttype=core&format=json
# {'doi': '10.1093/nar/gkw1039',
#  'pmcid': 'PMC5210535',
#  'pmid': '27899602',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1093%2Fnar%2Fgkw1128&resulttype=core&format=json
# {'doi': '10.1093/nar/gkw1128',
#  'pmcid': 'PMC5210586',
#  'pmid': '27899636',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.5582%2Firdr.2017.01003&resulttype=core&format=json
# {'doi': '10.5582/irdr.2017.01003',
#  'pmcid': 'PMC5359347',
#  'pmid': '28357175',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1504%2FIJDMB.2017.084268&resulttype=core&format=json
# https://api.crossref.org/works/10.1504/IJDMB.2017.084268
# {'doi': '10.1504/IJDMB.2017.084268',
#  'pmcid': None,
#  'pmid': None,
#  'pubyear': 2017}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1093%2Fnar%2Fgkw943&resulttype=core&format=json
# {'doi': '10.1093/nar/gkw943',
#  'pmcid': 'PMC5210640',
#  'pmid': '27924018',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1002%2Fhumu.23125&resulttype=core&format=json
# {'doi': '10.1002/humu.23125',
#  'pmcid': None,
#  'pmid': '27676360',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1093%2Fnar%2Fgkw1102&resulttype=core&format=json
# {'doi': '10.1093/nar/gkw1102',
#  'pmcid': 'PMC5210573',
#  'pmid': '27980099',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1007%2F978-1-4939-3743-1_4&resulttype=core&format=json
# {'doi': '10.1007/978-1-4939-3743-1_4',
#  'pmcid': None,
#  'pmid': '27812934',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1007%2F978-3-319-57741-8_1&resulttype=core&format=json
# https://api.crossref.org/works/10.1007/978-3-319-57741-8_1
# {'doi': '10.1007/978-3-319-57741-8_1',
#  'pmcid': None,
#  'pmid': None,
#  'pubyear': 2017}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1109%2FRIVF.2016.7800296&resulttype=core&format=json
# https://api.crossref.org/works/10.1109/RIVF.2016.7800296
# {'doi': '10.1109/RIVF.2016.7800296',
#  'pmcid': None,
#  'pmid': None,
#  'pubyear': 2016}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2Fs12859-016-1401-2&resulttype=core&format=json
# {'doi': '10.1186/s12859-016-1401-2',
#  'pmcid': 'PMC5142268',
#  'pmid': '27923364',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2Fs13059-016-1110-1&resulttype=core&format=json
# 'doi'
# https://api.crossref.org/works/10.1186/s13059-016-1110-1
# {'doi': '10.1186/s13059-016-1110-1',
#  'pmcid': None,
#  'pmid': None,
#  'pubyear': 2016}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1038%2Fncomms12521&resulttype=core&format=json
# {'doi': '10.1038/ncomms12521',
#  'pmcid': 'PMC5062569',
#  'pmid': '27725664',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1242%2Fdmm.026021&resulttype=core&format=json
# {'doi': '10.1242/dmm.026021',
#  'pmcid': 'PMC5087824',
#  'pmid': '27736745',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.3390%2Fijms17091555&resulttype=core&format=json
# {'doi': '10.3390/ijms17091555',
#  'pmcid': 'PMC5037827',
#  'pmid': '27649151',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1371%2Fjournal.pone.0162287&resulttype=core&format=json
# {'doi': '10.1371/journal.pone.0162287',
#  'pmcid': 'PMC5028053',
#  'pmid': '27643689',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2Fs12859-016-1205-4&resulttype=core&format=json
# {'doi': '10.1186/s12859-016-1205-4',
#  'pmcid': 'PMC5006367',
#  'pmid': '27578323',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1002%2Fhumu.23011&resulttype=core&format=json
# {'doi': '10.1002/humu.23011',
#  'pmcid': 'PMC4940263',
#  'pmid': '27158917',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1038%2Fgim.2015.161&resulttype=core&format=json
# {'doi': '10.1038/gim.2015.161',
#  'pmcid': 'PMC4902791',
#  'pmid': '26656649',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1534%2Fgenetics.116.188870&resulttype=core&format=json
# {'doi': '10.1534/genetics.116.188870',
#  'pmcid': 'PMC4981258',
#  'pmid': '27516611',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1007%2Fs40264-016-0414-0&resulttype=core&format=json
# {'doi': '10.1007/s40264-016-0414-0',
#  'pmcid': 'PMC4933310',
#  'pmid': '27003817',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1007%2Fs00439-016-1658-6&resulttype=core&format=json
# {'doi': '10.1007/s00439-016-1658-6',
#  'pmcid': 'PMC4883269',
#  'pmid': '27075447',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1007%2Fs00439-016-1662-x&resulttype=core&format=json
# {'doi': '10.1007/s00439-016-1662-x',
#  'pmcid': None,
#  'pmid': '27126233',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1038%2Fnm.4089&resulttype=core&format=json
#
# {'doi': '10.1038/nm.4089', 'pmcid': None, 'pmid': '24909912', 'pubyear': '2014'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1038%2Fnrg.2015.36&resulttype=core&format=json
# {'doi': '10.1038/nrg.2015.36',
#  'pmcid': None,
#  'pmid': '26875678',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2Fs13326-016-0047-3&resulttype=core&format=json
# {'doi': '10.1186/s13326-016-0047-3',
#  'pmcid': 'PMC4748471',
#  'pmid': '26865946',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1093%2Fnar%2Fgkv1317&resulttype=core&format=json
# {'doi': '10.1093/nar/gkv1317',
#  'pmcid': 'PMC4702921',
#  'pmid': '26615194',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1093%2Fdatabase%2Fbaw040&resulttype=core&format=json
# {'doi': '10.1093/database/baw040',
#  'pmcid': 'PMC4823819',
#  'pmid': '27055827',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.3389%2Ffnins.2016.00016&resulttype=core&format=json
# {'doi': '10.3389/fnins.2016.00016',
#  'pmcid': 'PMC4730103',
#  'pmid': '26858593',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1093%2Fnar%2Fgkv1329&resulttype=core&format=json
# {'doi': '10.1093/nar/gkv1329',
#  'pmcid': 'PMC4702926',
#  'pmid': '26656951',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1093%2Fnar%2Fgkv1222&resulttype=core&format=json
# {'doi': '10.1093/nar/gkv1222',
#  'pmcid': 'PMC4702865',
#  'pmid': '26582918',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2FS13326-016-0051-7&resulttype=core&format=json
#
# {'doi': '10.1186/S13326-016-0051-7',
#  'pmcid': 'PMC4804633',
#  'pmid': '27011785',
#  'pubyear': '2016'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1109%2FBIBM.2015.7359789&resulttype=core&format=json
# https://api.crossref.org/works/10.1109/BIBM.2015.7359789
# {'doi': '10.1109/BIBM.2015.7359789',
#  'pmcid': None,
#  'pmid': None,
#  'pubyear': 2015}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1038%2Fnrg3932&resulttype=core&format=json
# {'doi': '10.1038/nrg3932', 'pmcid': None, 'pmid': '26553330', 'pubyear': '2015'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1145%2F2808719.2812219&resulttype=core&format=json
# https://api.crossref.org/works/10.1145/2808719.2812219
# {'doi': '10.1145/2808719.2812219', 'pmcid': None, 'pmid': None, 'pubyear': 2015}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1038%2Fng.3425&resulttype=core&format=json
# {'doi': '10.1038/ng.3425', 'pmcid': None, 'pmid': '26506899', 'pubyear': '2015'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1016%2Fj.jbiotec.2017.06.008&resulttype=core&format=json
# {'doi': '10.1016/j.jbiotec.2017.06.008',
#  'pmcid': None,
#  'pmid': '28625679',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1016%2Fj.yebeh.2017.06.041&resulttype=core&format=json
# {'doi': '10.1016/j.yebeh.2017.06.041',
#  'pmcid': None,
#  'pmid': '28917501',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2Fs12859-017-1854-y&resulttype=core&format=json
#
# {'doi': '10.1186/s12859-017-1854-y',
#  'pmcid': 'PMC5324209',
#  'pmid': '28231758',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1002%2Fhumu.23278&resulttype=core&format=json
# {'doi': '10.1002/humu.23278',
#  'pmcid': None,
#  'pmid': '28699299',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1038%2Fnrg.2017.52&resulttype=core&format=json
# {'doi': '10.1038/nrg.2017.52',
#  'pmcid': None,
#  'pmid': '28804138',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1002%2Fajmg.c.31568&resulttype=core&format=json
# {'doi': '10.1002/ajmg.c.31568',
#  'pmcid': None,
#  'pmid': '28767187',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1016%2Fj.ecoinf.2017.06.003&resulttype=core&format=json
# https://api.crossref.org/works/10.1016/j.ecoinf.2017.06.003
# {'doi': '10.1016/j.ecoinf.2017.06.003',
#  'pmcid': None,
#  'pmid': None,
#  'pubyear': 2017}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.15252%2Fmsb.20156297&resulttype=core&format=json
# {'doi': '10.15252/msb.20156297',
#  'pmcid': 'PMC5615924',
#  'pmid': '28951502',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1002%2Fajmg.a.38318&resulttype=core&format=json
# {'doi': '10.1002/ajmg.a.38318',
#  'pmcid': None,
#  'pmid': '28586144',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1177%2F0883073817711527&resulttype=core&format=json
# {'doi': '10.1177/0883073817711527',
#  'pmcid': None,
#  'pmid': '28545339',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1038%2Fng.3901&resulttype=core&format=json
# {'doi': '10.1038/ng.3901', 'pmcid': None, 'pmid': '28650483', 'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1007%2Fs40291-017-0257-0&resulttype=core&format=json
# {'doi': '10.1007/s40291-017-0257-0',
#  'pmcid': None,
#  'pmid': '28197949',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1093%2Fbioinformatics%2Fbtx238&resulttype=core&format=json
# {'doi': '10.1093/bioinformatics/btx238',
#  'pmcid': None,
#  'pmid': '28881973',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1093%2Fnar%2Fgkx445&resulttype=core&format=json
# {'doi': '10.1093/nar/gkx445',
#  'pmcid': 'PMC5570161',
#  'pmid': '28535294',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1080%2F17460441.2017.1329296&resulttype=core&format=json
# {'doi': '10.1080/17460441.2017.1329296',
#  'pmcid': None,
#  'pmid': '28494630',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1371%2Fjournal.pone.0180682&resulttype=core&format=json
# {'doi': '10.1371/journal.pone.0180682',
#  'pmcid': 'PMC5503261',
#  'pmid': '28700664',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1111%2Fjth.13681&resulttype=core&format=json
# {'doi': '10.1111/jth.13681',
#  'pmcid': None,
#  'pmid': '28671349',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1093%2Filar%2Filx013&resulttype=core&format=json
# {'doi': '10.1093/ilar/ilx013',
#  'pmcid': None,
#  'pmid': '28838066',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1016%2Fj.preteyeres.2017.03.003&resulttype=core&format=json
# {'doi': '10.1016/j.preteyeres.2017.03.003',
#  'pmcid': None,
#  'pmid': '28363849',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1016%2Fj.ajhg.2017.04.003&resulttype=core&format=json
# {'doi': '10.1016/j.ajhg.2017.04.003',
#  'pmcid': 'PMC5420351',
#  'pmid': '28475856',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1371%2Fjournal.pone.0174964&resulttype=core&format=json
# {'doi': '10.1371/journal.pone.0174964',
#  'pmcid': 'PMC5384674',
#  'pmid': '28388656',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1038%2Fng.3827&resulttype=core&format=json
# {'doi': '10.1038/ng.3827', 'pmcid': None, 'pmid': '28358133', 'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2Fs40246-017-0107-5&resulttype=core&format=json
# {'doi': '10.1186/s40246-017-0107-5',
#  'pmcid': 'PMC5441048',
#  'pmid': '28532469',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1186%2Fs12920-017-0246-5&resulttype=core&format=json
# {'doi': '10.1186/s12920-017-0246-5',
#  'pmcid': 'PMC5322674',
#  'pmid': '28228131',
#  'pubyear': '2017'}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.1504%2FIJDMB.2017.087181&resulttype=core&format=json
# https://api.crossref.org/works/10.1504/IJDMB.2017.087181
# {'doi': '10.1504/IJDMB.2017.087181',
#  'pmcid': None,
#  'pmid': None,
#  'pubyear': 2017}
# http://www.ebi.ac.uk/europepmc/webservices/rest/search?query=10.12688%2Ff1000research.10788.1&resulttype=core&format=json
# {'doi': '10.12688/f1000research.10788.1',
#  'pmcid': 'PMC5414807',
#  'pmid': '28529714',
#  'pubyear': '2017'}

# %%
newFrame = pd.DataFrame(data=results)
newFrame.to_csv('mapped_ids.csv')

# %%
newFrame
# Out:
#                                  doi       pmcid      pmid pubyear
# 0      10.1080/03610926.2016.1197254        None      None    2016
# 1          10.1016/j.jbi.2017.07.012        None  28729030    2017
# 2          10.1007/s11427-017-9099-3        None  28639105    2017
# 3          10.1007/s00103-017-2538-5        None  28293716    2017
# 4           10.3389/FPUBH.2017.00066  PMC5379772  28421178    2017
# 5          10.1186/s12864-016-3263-4  PMC5310285  28198675    2017
# 6                  10.2144/000114492        None  28118812    2017
# 7                10.1093/nar/gkw1039  PMC5210535  27899602    2017
# 8                10.1093/nar/gkw1128  PMC5210586  27899636    2017
# 9            10.5582/irdr.2017.01003  PMC5359347  28357175    2017
# 10         10.1504/IJDMB.2017.084268        None      None    2017
# 11                10.1093/nar/gkw943  PMC5210640  27924018    2017
# 12                10.1002/humu.23125        None  27676360    2017
# 13               10.1093/nar/gkw1102  PMC5210573  27980099    2017
# 14       10.1007/978-1-4939-3743-1_4        None  27812934    2017
# 15       10.1007/978-3-319-57741-8_1        None      None    2017
# 16         10.1109/RIVF.2016.7800296        None      None    2016
# 17         10.1186/s12859-016-1401-2  PMC5142268  27923364    2016
# 18         10.1186/s13059-016-1110-1        None      None    2016
# 19               10.1038/ncomms12521  PMC5062569  27725664    2016
# 20                10.1242/dmm.026021  PMC5087824  27736745    2016
# 21              10.3390/ijms17091555  PMC5037827  27649151    2016
# 22      10.1371/journal.pone.0162287  PMC5028053  27643689    2016
# 23         10.1186/s12859-016-1205-4  PMC5006367  27578323    2016
# 24                10.1002/humu.23011  PMC4940263  27158917    2016
# 25              10.1038/gim.2015.161  PMC4902791  26656649    2016
# 26       10.1534/genetics.116.188870  PMC4981258  27516611    2016
# 27         10.1007/s40264-016-0414-0  PMC4933310  27003817    2016
# 28         10.1007/s00439-016-1658-6  PMC4883269  27075447    2016
# 29         10.1007/s00439-016-1662-x        None  27126233    2016
# ..                               ...         ...       ...     ...
# 39         10.1109/BIBM.2015.7359789        None      None    2015
# 40                   10.1038/nrg3932        None  26553330    2015
# 41           10.1145/2808719.2812219        None      None    2015
# 42                   10.1038/ng.3425        None  26506899    2015
# 43     10.1016/j.jbiotec.2017.06.008        None  28625679    2017
# 44       10.1016/j.yebeh.2017.06.041        None  28917501    2017
# 45         10.1186/s12859-017-1854-y  PMC5324209  28231758    2017
# 46                10.1002/humu.23278        None  28699299    2017
# 47               10.1038/nrg.2017.52        None  28804138    2017
# 48              10.1002/ajmg.c.31568        None  28767187    2017
# 49      10.1016/j.ecoinf.2017.06.003        None      None    2017
# 50             10.15252/msb.20156297  PMC5615924  28951502    2017
# 51              10.1002/ajmg.a.38318        None  28586144    2017
# 52          10.1177/0883073817711527        None  28545339    2017
# 53                   10.1038/ng.3901        None  28650483    2017
# 54         10.1007/s40291-017-0257-0        None  28197949    2017
# 55     10.1093/bioinformatics/btx238        None  28881973    2017
# 56                10.1093/nar/gkx445  PMC5570161  28535294    2017
# 57     10.1080/17460441.2017.1329296        None  28494630    2017
# 58      10.1371/journal.pone.0180682  PMC5503261  28700664    2017
# 59                 10.1111/jth.13681        None  28671349    2017
# 60               10.1093/ilar/ilx013        None  28838066    2017
# 61  10.1016/j.preteyeres.2017.03.003        None  28363849    2017
# 62        10.1016/j.ajhg.2017.04.003  PMC5420351  28475856    2017
# 63      10.1371/journal.pone.0174964  PMC5384674  28388656    2017
# 64                   10.1038/ng.3827        None  28358133    2017
# 65         10.1186/s40246-017-0107-5  PMC5441048  28532469    2017
# 66         10.1186/s12920-017-0246-5  PMC5322674  28228131    2017
# 67         10.1504/IJDMB.2017.087181        None      None    2017
# 68    10.12688/f1000research.10788.1  PMC5414807  28529714    2017
#
# [69 rows x 4 columns]
